# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

tips = sns.load_dataset("tips")

g = sns.jointplot(data=tips
                  ,x="total_bill"
                  ,y="tip" 
                  ,hue='sex'
                  ,kind="kde" # kind{ “scatter” | “kde” | “hist” | “hex” | “reg” | “resid” }
                  ,truncate=False
                  ,xlim=(0, 60), ylim=(0, 12)
                  ,height=4, ratio=3
                  ,color="m")
# Out:
# C:\Users\fallg\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'truncate'
#   cset = contour_func(

# %%
g = sns.JointGrid(height=4, ratio=3)
x, y = penguins["bill_length_mm"], penguins["bill_depth_mm"]

sns.scatterplot(x=x, y=y, ec="b", fc="none", s=100, linewidth=1.5, ax=g.ax_joint)
sns.histplot(x=x, fill=False, linewidth=2, ax=g.ax_marg_x)
sns.kdeplot(y=y, linewidth=2, ax=g.ax_marg_y)
g.refline(x=45, y=16)

# %%
g = sns.JointGrid(data=penguins, x="bill_length_mm", y="bill_depth_mm",height=4, ratio=3)
g.plot(sns.regplot
       #, sns.boxplot
       , sns.histplot)

# %%
g = sns.JointGrid(data=penguins, x="bill_length_mm", y="bill_depth_mm",height=4, ratio=3)
g.plot(sns.regplot
       , sns.boxplot
       #, sns.histplot
      )

# %%
g = sns.JointGrid(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", height=4, ratio=3)
g.plot(sns.scatterplot, sns.histplot)

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
penguins = sns.load_dataset("penguins")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", kind="reg")

# %%
sns.hls_palette(n_colors=6, h=0.01, s=0.9, l=0.65, as_cmap=False)
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", height=5, ratio=2, marginal_ticks=True)

# %%
sns.husl_palette(as_cmap=True)

# %%
sns.hls_palette(n_colors=10, h=0.01, s=0.9, l=0.65, as_cmap=True)

# %%
sns.hls_palette(n_colors=10, h=0.01, s=0.9, l=0.65, as_cmap=False)
# Out:
# [(0.965, 0.3728000000000001, 0.3350000000000001),
#  (0.965, 0.7508, 0.3350000000000001),
#  (0.8011999999999999, 0.965, 0.3350000000000001),
#  (0.4232, 0.965, 0.3350000000000001),
#  (0.3350000000000001, 0.965, 0.6248000000000002),
#  (0.3350000000000001, 0.9271999999999998, 0.965),
#  (0.3350000000000001, 0.5491999999999996, 0.965),
#  (0.49880000000000047, 0.3350000000000001, 0.965),
#  (0.8767999999999999, 0.3350000000000001, 0.965),
#  (0.965, 0.3350000000000001, 0.6751999999999999)]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def sinplot(n=10, flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, n + 1):
        plt.plot(x, np.sin(x + i * .5) * (n + 2 - i) * flip)

# %%
sinplot()

# %%
sinplot()
sns.despine()

# %%
sinplot()
sns.despine(offset=10, trim=True);

# %%
sns.set_style("whitegrid")
sns.boxplot(data=penguins["bill_length_mm"], palette="deep")
sns.despine(left=True)

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

with sns.axes_style("darkgrid"):
    ax = f.add_subplot(gs[0, 0])
    sinplot(6)

with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 1])
    sinplot(6)

with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 0])
    sinplot(6)

with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[1, 1])
    sinplot(6)

f.tight_layout()
