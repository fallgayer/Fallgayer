# %% [markdown]
# # Z Score por Atributo
# Classificação de coluna Z Score por atritubo

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Criando o intervalo de datas de jan/21 a dez/25
dates = pd.date_range(start='2021-01-31', end='2025-12-31', freq='M')

# Criando valores aleatórios entre 80 e 130
np.random.seed(0)
values = np.random.randint(80, 131, size=len(dates))

# Criando o DataFrame
df = pd.DataFrame({'date': dates, 'value': values})

# Visualizando as primeiras linhas do DataFrame
print(df.head())
# Out:
#         date  value
# 0 2021-01-31    124
# 1 2021-02-28    127
# 2 2021-03-31     80
# 3 2021-04-30     83
# 4 2021-05-31     83

# %%
import warnings

# Suprimindo alertas sobre pacotes que irão expirar
warnings.filterwarnings("ignore")

# %%
# O dataframe tem N linhas e N colunas
df.shape
# Out:
# (60, 2)

# %%
df.describe()
# Out:
#                       date       value
# count                   60   60.000000
# mean   2023-07-16 07:12:00  102.733333
# min    2021-01-31 00:00:00   80.000000
# 25%    2022-04-22 12:00:00   89.750000
# 50%    2023-07-15 12:00:00  103.000000
# 75%    2024-10-07 18:00:00  115.250000
# max    2025-12-31 00:00:00  130.000000
# std                    NaN   14.952883

# %%
#Visualizando o que foi criado...

plt.figure(figsize=(12, 4)) # (largura, altura)
sns.lineplot(x="date", y="value"
             ,data=df)
plt.title('Valores aleatórios criados no df',fontsize=10) 
plt.xlabel('60 meses, um mês em cada linha de registro do df',fontsize=8) 
plt.ylabel('Valores',fontsize=8)
# Out:
# Text(0, 0.5, 'Valores')

# %%
# Uma visão de histograma
plt.figure(figsize=(10, 4)) # (largura, altura)
sns.histplot(data=df, x="value"
            #,binwidth=6
            ,bins=8
            ,kde=True
            #,element="poly"
            #,element='step'
            #,hue="event" # separa em grupos pelos atributos de coluna
            #,err_style="bars",errorbar=("se", 2)
            #,estimator=None, lw=1
            #,stat="density" # Alterna a quantidade para a densidade %
            #,stat="percent"
            #,discrete=True
            #,discrete=(True, True), log_scale=(True, True) # entra com os pares x,y
            #,common_norm=True
            #,shrink=2    # espaçamento
            #,multiple="dodge"
            #,log_scale=True # escala no x fica em logaritimo
            #,fill=False # preenchimento false = vazio (fica só as bordas)
            #,hue_order=["Radial Velocity", "Transit"],#ordem em que as colunas aparecem
            #,legend=False
            #,cumulative=True
            #,thresh=None
            #,pthresh=.05, pmax=.9
            #,cbar=True, cbar_kws=dict(shrink=.75) # barra de densidade fora do gráfico
            )
# Out:
# <Axes: xlabel='value', ylabel='Count'>

# %%
# Calculando o indicador "sw" (abreviatura de gangorra em inglês - (seesaw) ) - Média Móvel 6m 3a3
# É um comparativo dos últimos 3 meses comparado aos 3 anteriores
# Se positivo, indica que cresceu e o percetual é o próprio crescimento. Da mesma forma a indicação de queda.
sw_values = []

for i in range(len(df)):
    if i < 3:
        sw_values.append(np.nan)  # Para os primeiros 3 meses, não temos dados suficientes para calcular "sw"
    else:
        sw = df.iloc[i]['value'] + df.iloc[i - 1]['value'] + df.iloc[i - 2]['value']
        sw /= (df.iloc[i - 3]['value'] + df.iloc[i - 4]['value'] + df.iloc[i - 5]['value'])
        sw_values.append(sw)

# Adicionando a coluna "sw" ao DataFrame
df['sw'] = sw_values

df.head(10)
# Out:
#         date  value        sw
# 0 2021-01-31    124       NaN
# 1 2021-02-28    127       NaN
# 2 2021-03-31     80       NaN
# 3 2021-04-30     83  0.886850
# 4 2021-05-31     83  0.666667
# 5 2021-06-30    119  0.861027
# 6 2021-07-31     89  1.003448
# 7 2021-08-31     99  1.247967
# 8 2021-09-30    101  1.014035
# 9 2021-10-31    130  1.134021

# %%
# corrigir os nulos para zero
#df['sw']=df['sw'].fillna(value=0)

# Para fins estatísticos o sw ficará melhor com a média.
df['sw']=df['sw'].fillna(df['sw'].mean())

# %%
df.head(6)
# Out:
#         date  value        sw
# 0 2021-01-31    124  0.999053
# 1 2021-02-28    127  0.999053
# 2 2021-03-31     80  0.999053
# 3 2021-04-30     83  0.886850
# 4 2021-05-31     83  0.666667
# 5 2021-06-30    119  0.861027

# %%
# Enviar para o excel para dar uma olhada...
# Em windows fica salvo normalmente em C:\Users\'seu usuário do windows' [[padrão de instalação do Anaconda]]
df.to_excel('z-score atributo.xlsx', index=False)

# %%
# Calculando a média e o desvio padrão dos [valores] (não da SW)
value_mean = df['value'].mean()
value_std = df['value'].std()

# Calculando o valor Z para cada valor de "sw"
df['z_value'] = (df['value'] - value_mean) / value_std

df.head(6)
# Out:
#         date  value        sw   z_value
# 0 2021-01-31    124  0.999053  1.422245
# 1 2021-02-28    127  0.999053  1.622875
# 2 2021-03-31     80  0.999053 -1.520331
# 3 2021-04-30     83  0.886850 -1.319701
# 4 2021-05-31     83  0.666667 -1.319701
# 5 2021-06-30    119  0.861027  1.087862

# %%
# Calculando a média e o desvio padrão de SW)
sw_mean = df['sw'].mean()
sw_std = df['sw'].std()

# Calculando o valor Z para cada valor de "sw"
df['z_sw'] = (df['sw'] - sw_mean) / sw_std

df.head(6)
# Out:
#         date  value        sw   z_value      z_sw
# 0 2021-01-31    124  0.999053  1.422245  0.000000
# 1 2021-02-28    127  0.999053  1.622875  0.000000
# 2 2021-03-31     80  0.999053 -1.520331  0.000000
# 3 2021-04-30     83  0.886850 -1.319701 -0.949585
# 4 2021-05-31     83  0.666667 -1.319701 -2.813022
# 5 2021-06-30    119  0.861027  1.087862 -1.168128

# %%
# Atribuindo a descrição categórica com base nos valores Z
def cria_z_score(z_score):
    if z_score < -0.5:
        return 'Baixa'
    elif z_score >= -0.5 and z_score <= 0.5:
        return 'Média'
    else:
        return 'Alta'

    # zd = Score Z e D descritivo
df['zd_value'] = df['z_value'].apply(cria_z_score)

# Visualizando o DataFrame com a nova coluna
df.head(6)
# Out:
#         date  value        sw   z_value      z_sw zd_value
# 0 2021-01-31    124  0.999053  1.422245  0.000000     Alta
# 1 2021-02-28    127  0.999053  1.622875  0.000000     Alta
# 2 2021-03-31     80  0.999053 -1.520331  0.000000    Baixa
# 3 2021-04-30     83  0.886850 -1.319701 -0.949585    Baixa
# 4 2021-05-31     83  0.666667 -1.319701 -2.813022    Baixa
# 5 2021-06-30    119  0.861027  1.087862 -1.168128     Alta

# %%
# Atribuindo a descrição categórica com base nos valores Z
def cria_z_score(z_score):
    if z_score < -0.5:
        return 'Baixa'
    elif z_score >= -0.5 and z_score <= 0.5:
        return 'Média'
    else:
        return 'Alta'

df['zd_sw'] = df['z_sw'].apply(cria_z_score)

# Visualizando o DataFrame com a nova coluna
df.head(6)
# Out:
#         date  value        sw   z_value      z_sw zd_value  zd_sw
# 0 2021-01-31    124  0.999053  1.422245  0.000000     Alta  Média
# 1 2021-02-28    127  0.999053  1.622875  0.000000     Alta  Média
# 2 2021-03-31     80  0.999053 -1.520331  0.000000    Baixa  Média
# 3 2021-04-30     83  0.886850 -1.319701 -0.949585    Baixa  Baixa
# 4 2021-05-31     83  0.666667 -1.319701 -2.813022    Baixa  Baixa
# 5 2021-06-30    119  0.861027  1.087862 -1.168128     Alta  Baixa

# %%
sns.pairplot(df, corner=True, hue='zd_value', hue_order=['Baixa','Média','Alta'])

# %%
sns.pairplot(df, corner=True, hue='zd_sw', hue_order=['Baixa','Média','Alta'])

# %%
df.boxplot(column=['sw','z_value','z_sw'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['value','sw','z_value','z_sw'])
# Out:
# <Axes: >

# %%
plt.subplot(1, 4, 1) # (1,4,1)=(linhas,colunas,posição)
df.boxplot(column=['value'])
plt.title('Valores do df') 
plt.xlabel('-') 
plt.ylabel('Valores') 
plt.subplot(1, 4, 2) 
df.boxplot(column=['sw'])
plt.title('Sw - 3 / 3') 
plt.xlabel('-') 
plt.ylabel('% Cresc/Decr') 
plt.subplot(1, 4, 3) 
df.boxplot(column=['z_value'])
plt.title('Z-value') 
plt.xlabel('-') 
plt.ylabel('Desvio padrão valores') 
plt.subplot(1, 4, 4) 
df.boxplot(column=['z_sw'])
plt.title('Z-sw') 
plt.xlabel('-') 
plt.ylabel('Desvio padrão sw') 


plt.tight_layout() # melhora o espaçamento
plt.show()

# %%
plt.subplot(1, 3, 1) 
df.boxplot(column=['value'])
plt.title('Valores do df') 
plt.xlabel('-') 
plt.ylabel('Valores') 
plt.subplot(1, 3, 2) 
df.boxplot(column=['sw'])
plt.title('Sw - 3 / 3') 
plt.xlabel('-') 
plt.ylabel('% Cresc/Decr') 
plt.subplot(1, 3, 3) 
df.boxplot(column=['z_value'])
plt.title('Z-Value') 
plt.xlabel('-') 
plt.ylabel('Desvio padrão') 
#plt.axvspan(xmin=1.5, xmax=1.75, ymin=0, ymax=2, color='#d9d9d9', alpha=0.5) #marca uma área do gráfico VERTICAL
plt.axhspan(ymin=-(sw_mean + sw_std), ymax=(sw_mean + sw_std)
            ,color='#ccc' # R G B
            ,alpha=.5 # transparencia, 0.1 muito transparente, .9 nada transparente
           ) #marca uma área do gráfico HORIZONTAL

plt.tight_layout() # melhora o espaçamento
plt.show()

# %%
# Define o estilo do seaborn
sns.set(style="whitegrid")

# Obtém as colunas numéricas e categóricas separadamente
numeric_columns = df.select_dtypes(include=['float64', 'int64'])
categorical_columns = df.select_dtypes(include=['category', 'object'])

# Define o tamanho da figura
plt.figure(figsize=(8, 12))

# Itera sobre cada coluna numérica do DataFrame

for i, column in enumerate(numeric_columns.columns):
    plt.subplot(3, 4, i+1)  # Ajusta o layout dos subplots conforme necessário
    sns.boxplot(y=column, data=df)  # Cria um boxplot para a coluna atual
    
    # Adiciona título à subplot
    plt.title(f"|> {column}")

# Ajusta o espaço entre os subplots verticais
plt.subplots_adjust(hspace=.5, wspace=2)

# Define o tamanho da figura
plt.figure(figsize=(12, 12))

# Itera sobre cada coluna categórica do DataFrame

for i, column in enumerate(categorical_columns.columns):
    plt.subplot(3, 3, i+1)  # Ajusta o layout dos subplots conforme necessário
    sns.countplot(x=column, data=df)  # Cria um countplot para a coluna atual
    
    # Adiciona título à subplot
    plt.title(f"Countplot de {column}")

# Ajusta o layout da figura e exibe os gráficos
plt.tight_layout()
plt.show()

# %%
df.head(6)
# Out:
#         date  value        sw   z_value      z_sw zd_value  zd_sw
# 0 2021-01-31    124  0.999053  1.422245  0.000000     Alta  Média
# 1 2021-02-28    127  0.999053  1.622875  0.000000     Alta  Média
# 2 2021-03-31     80  0.999053 -1.520331  0.000000    Baixa  Média
# 3 2021-04-30     83  0.886850 -1.319701 -0.949585    Baixa  Baixa
# 4 2021-05-31     83  0.666667 -1.319701 -2.813022    Baixa  Baixa
# 5 2021-06-30    119  0.861027  1.087862 -1.168128     Alta  Baixa

# %%
# Atribuindo a descrição categórica com base nos valores Z
def categorize_z_score(z_score):
    if z_score > -0.5 and z_score <= 0.5:
        return 'Estável'
    elif z_score > 0.5 and z_score <= 1:
        return 'Pouco alto'
    elif z_score > 1:
        return 'Muito alto'
    elif z_score > -1 and z_score <= -0.5:
        return 'Pouco baixo'
    else:
        return 'Muito baixo'

df['zf_value'] = df['z_value'].apply(categorize_z_score)

# Visualizando o DataFrame com a nova coluna
print(df)
# Out:
#          date  value        sw   z_value      z_sw zd_value  zd_sw  \
# 0  2021-01-31    124  0.999053  1.422245  0.000000     Alta  Média
# 1  2021-02-28    127  0.999053  1.622875  0.000000     Alta  Média
# 2  2021-03-31     80  0.999053 -1.520331  0.000000    Baixa  Média
# 3  2021-04-30     83  0.886850 -1.319701 -0.949585    Baixa  Baixa
# 4  2021-05-31     83  0.666667 -1.319701 -2.813022    Baixa  Baixa
# 5  2021-06-30    119  0.861027  1.087862 -1.168128     Alta  Baixa
# 6  2021-07-31     89  1.003448 -0.918441  0.037197    Baixa  Média
# 7  2021-08-31     99  1.247967 -0.249673  2.106590    Média   Alta
# 8  2021-09-30    101  1.014035 -0.115920  0.126795    Média  Média
# 9  2021-10-31    130  1.134021  1.823506  1.142245     Alta   Alta
# 10 2021-11-30    116  1.130293  0.887231  1.110699     Alta   Alta
# 11 2021-12-31    103  1.207612  0.017834  1.765061    Média   Alta
# 12 2022-01-31     86  0.924242 -1.119071 -0.633130    Baixa  Baixa
# 13 2022-02-28    104  0.844380  0.084711 -1.309011    Média  Baixa
# 14 2022-03-31    104  0.842407  0.084711 -1.325713    Média  Baixa
# 15 2022-04-30     92  0.983607 -0.717810 -0.130725    Baixa  Média
# 16 2022-05-31     81  0.945392 -1.453454 -0.454135    Baixa  Média
# 17 2022-06-30    118  0.989796  1.020985 -0.078344     Alta  Média
# 18 2022-07-31    119  1.060000  1.087862  0.515801     Alta   Alta
# 19 2022-08-31    103  1.227437  0.017834  1.932836    Média   Alta
# 20 2022-09-30    126  1.195876  1.555999  1.665736     Alta   Alta
# 21 2022-10-31    104  1.047170  0.084711  0.407217    Média  Média
# 22 2022-11-30     97  0.961765 -0.383427 -0.315575    Média  Média
# 23 2022-12-31    117  0.913793  0.954108 -0.721564     Alta  Baixa
# 24 2023-01-31    105  0.957958  0.151587 -0.347792    Média  Média
# 25 2023-02-28     93  0.963303 -0.650934 -0.302559    Baixa  Média
# 26 2023-03-31     88  0.899371 -0.985317 -0.843619    Baixa  Baixa
# 27 2023-04-30     89  0.846395 -0.918441 -1.291962    Baixa  Baixa
# 28 2023-05-31    100  0.879365 -0.182796 -1.012932    Média  Baixa
# 29 2023-06-30     96  0.996503 -0.450303 -0.021577    Média  Média
# 30 2023-07-31     85  1.040741 -1.185947  0.352807    Baixa  Média
# 31 2023-08-31     95  0.996390 -0.517180 -0.022539    Baixa  Média
# 32 2023-09-30    127  1.077193  1.622875  0.661307     Alta   Alta
# 33 2023-10-31     80  1.074733 -1.520331  0.640488    Baixa   Alta
# 34 2023-11-30     98  1.105072 -0.316550  0.897254    Média   Alta
# 35 2023-12-31    115  0.954397  0.820355 -0.377926     Alta  Média
# 36 2024-01-31    104  1.049669  0.084711  0.428367    Média  Média
# 37 2024-02-29    129  1.140984  1.756629  1.201174     Alta   Alta
# 38 2024-03-31    109  1.167235  0.419094  1.423346    Média   Alta
# 39 2024-04-30     99  1.063091 -0.249673  0.541964    Média   Alta
# 40 2024-05-31     99  0.882184 -0.249673 -0.989076    Média  Baixa
# 41 2024-06-30     94  0.853801 -0.584057 -1.229282    Baixa  Baixa
# 42 2024-07-31    119  0.925816  1.087862 -0.619813     Alta  Baixa
# 43 2024-08-31    112  1.058632  0.619724  0.504222     Alta   Alta
# 44 2024-09-30     81  1.068493 -1.453454  0.587679    Baixa   Alta
# 45 2024-10-31     89  0.903846 -0.918441 -0.805746    Baixa  Baixa
# 46 2024-11-30    112  0.867692  0.619724 -1.111720     Alta  Baixa
# 47 2024-12-31    111  1.000000  0.552848  0.008014     Alta  Média
# 48 2025-01-31     90  1.109929 -0.851564  0.938356    Baixa   Alta
# 49 2025-02-28    103  1.078014  0.017834  0.668257    Média   Alta
# 50 2025-03-31    115  0.987179  0.820355 -0.100487     Alta  Média
# 51 2025-04-30     91  0.987220 -0.784687 -0.100141    Baixa  Média
# 52 2025-05-31    130  1.105263  1.823506  0.898868     Alta   Alta
# 53 2025-06-30    108  1.068182  0.352217  0.585044    Média   Alta
# 54 2025-07-31    114  1.139159  0.753478  1.185728     Alta   Alta
# 55 2025-08-31     80  0.898810 -1.520331 -0.848372    Baixa  Baixa
# 56 2025-09-30     80  0.832827 -1.520331 -1.406791    Baixa  Baixa
# 57 2025-10-31    116  0.784091  0.887231 -1.819248     Alta  Baixa
# 58 2025-11-30     85  0.930464 -1.185947 -0.580480    Baixa  Baixa
# 59 2025-12-31    118  1.164234  1.020985  1.397941     Alta   Alta
#
#        zf_value
# 0    Muito alto
# 1    Muito alto
# 2   Muito baixo
# 3   Muito baixo
# 4   Muito baixo
# 5    Muito alto
# 6   Pouco baixo
# 7       Estável
# 8       Estável
# 9    Muito alto
# 10   Pouco alto
# 11      Estável
# 12  Muito baixo
# 13      Estável
# 14      Estável
# 15  Pouco baixo
# 16  Muito baixo
# 17   Muito alto
# 18   Muito alto
# 19      Estável
# 20   Muito alto
# 21      Estável
# 22      Estável
# 23   Pouco alto
# 24      Estável
# 25  Pouco baixo
# 26  Pouco baixo
# 27  Pouco baixo
# 28      Estável
# 29      Estável
# 30  Muito baixo
# 31  Pouco baixo
# 32   Muito alto
# 33  Muito baixo
# 34      Estável
# 35   Pouco alto
# 36      Estável
# 37   Muito alto
# 38      Estável
# 39      Estável
# 40      Estável
# 41  Pouco baixo
# 42   Muito alto
# 43   Pouco alto
# 44  Muito baixo
# 45  Pouco baixo
# 46   Pouco alto
# 47   Pouco alto
# 48  Pouco baixo
# 49      Estável
# 50   Pouco alto
# 51  Pouco baixo
# 52   Muito alto
# 53      Estável
# 54   Pouco alto
# 55  Muito baixo
# 56  Muito baixo
# 57   Pouco alto
# 58  Muito baixo
# 59   Muito alto

# %%
# Atribuindo a descrição categórica com base nos valores Z
def categorize_z_score(z_score):
    if z_score > -0.5 and z_score <= 0.5:
        return 'Estável'
    elif z_score > 0.5 and z_score <= 1:
        return 'Pouco alto'
    elif z_score > 1:
        return 'Muito alto'
    elif z_score > -1 and z_score <= -0.5:
        return 'Pouco baixo'
    else:
        return 'Muito baixo'

df['zf_sw'] = df['z_sw'].apply(categorize_z_score)

# Visualizando o DataFrame com a nova coluna
print(df)
# Out:
#          date  value        sw   z_value      z_sw zd_value  zd_sw  \
# 0  2021-01-31    124  0.999053  1.422245  0.000000     Alta  Média
# 1  2021-02-28    127  0.999053  1.622875  0.000000     Alta  Média
# 2  2021-03-31     80  0.999053 -1.520331  0.000000    Baixa  Média
# 3  2021-04-30     83  0.886850 -1.319701 -0.949585    Baixa  Baixa
# 4  2021-05-31     83  0.666667 -1.319701 -2.813022    Baixa  Baixa
# 5  2021-06-30    119  0.861027  1.087862 -1.168128     Alta  Baixa
# 6  2021-07-31     89  1.003448 -0.918441  0.037197    Baixa  Média
# 7  2021-08-31     99  1.247967 -0.249673  2.106590    Média   Alta
# 8  2021-09-30    101  1.014035 -0.115920  0.126795    Média  Média
# 9  2021-10-31    130  1.134021  1.823506  1.142245     Alta   Alta
# 10 2021-11-30    116  1.130293  0.887231  1.110699     Alta   Alta
# 11 2021-12-31    103  1.207612  0.017834  1.765061    Média   Alta
# 12 2022-01-31     86  0.924242 -1.119071 -0.633130    Baixa  Baixa
# 13 2022-02-28    104  0.844380  0.084711 -1.309011    Média  Baixa
# 14 2022-03-31    104  0.842407  0.084711 -1.325713    Média  Baixa
# 15 2022-04-30     92  0.983607 -0.717810 -0.130725    Baixa  Média
# 16 2022-05-31     81  0.945392 -1.453454 -0.454135    Baixa  Média
# 17 2022-06-30    118  0.989796  1.020985 -0.078344     Alta  Média
# 18 2022-07-31    119  1.060000  1.087862  0.515801     Alta   Alta
# 19 2022-08-31    103  1.227437  0.017834  1.932836    Média   Alta
# 20 2022-09-30    126  1.195876  1.555999  1.665736     Alta   Alta
# 21 2022-10-31    104  1.047170  0.084711  0.407217    Média  Média
# 22 2022-11-30     97  0.961765 -0.383427 -0.315575    Média  Média
# 23 2022-12-31    117  0.913793  0.954108 -0.721564     Alta  Baixa
# 24 2023-01-31    105  0.957958  0.151587 -0.347792    Média  Média
# 25 2023-02-28     93  0.963303 -0.650934 -0.302559    Baixa  Média
# 26 2023-03-31     88  0.899371 -0.985317 -0.843619    Baixa  Baixa
# 27 2023-04-30     89  0.846395 -0.918441 -1.291962    Baixa  Baixa
# 28 2023-05-31    100  0.879365 -0.182796 -1.012932    Média  Baixa
# 29 2023-06-30     96  0.996503 -0.450303 -0.021577    Média  Média
# 30 2023-07-31     85  1.040741 -1.185947  0.352807    Baixa  Média
# 31 2023-08-31     95  0.996390 -0.517180 -0.022539    Baixa  Média
# 32 2023-09-30    127  1.077193  1.622875  0.661307     Alta   Alta
# 33 2023-10-31     80  1.074733 -1.520331  0.640488    Baixa   Alta
# 34 2023-11-30     98  1.105072 -0.316550  0.897254    Média   Alta
# 35 2023-12-31    115  0.954397  0.820355 -0.377926     Alta  Média
# 36 2024-01-31    104  1.049669  0.084711  0.428367    Média  Média
# 37 2024-02-29    129  1.140984  1.756629  1.201174     Alta   Alta
# 38 2024-03-31    109  1.167235  0.419094  1.423346    Média   Alta
# 39 2024-04-30     99  1.063091 -0.249673  0.541964    Média   Alta
# 40 2024-05-31     99  0.882184 -0.249673 -0.989076    Média  Baixa
# 41 2024-06-30     94  0.853801 -0.584057 -1.229282    Baixa  Baixa
# 42 2024-07-31    119  0.925816  1.087862 -0.619813     Alta  Baixa
# 43 2024-08-31    112  1.058632  0.619724  0.504222     Alta   Alta
# 44 2024-09-30     81  1.068493 -1.453454  0.587679    Baixa   Alta
# 45 2024-10-31     89  0.903846 -0.918441 -0.805746    Baixa  Baixa
# 46 2024-11-30    112  0.867692  0.619724 -1.111720     Alta  Baixa
# 47 2024-12-31    111  1.000000  0.552848  0.008014     Alta  Média
# 48 2025-01-31     90  1.109929 -0.851564  0.938356    Baixa   Alta
# 49 2025-02-28    103  1.078014  0.017834  0.668257    Média   Alta
# 50 2025-03-31    115  0.987179  0.820355 -0.100487     Alta  Média
# 51 2025-04-30     91  0.987220 -0.784687 -0.100141    Baixa  Média
# 52 2025-05-31    130  1.105263  1.823506  0.898868     Alta   Alta
# 53 2025-06-30    108  1.068182  0.352217  0.585044    Média   Alta
# 54 2025-07-31    114  1.139159  0.753478  1.185728     Alta   Alta
# 55 2025-08-31     80  0.898810 -1.520331 -0.848372    Baixa  Baixa
# 56 2025-09-30     80  0.832827 -1.520331 -1.406791    Baixa  Baixa
# 57 2025-10-31    116  0.784091  0.887231 -1.819248     Alta  Baixa
# 58 2025-11-30     85  0.930464 -1.185947 -0.580480    Baixa  Baixa
# 59 2025-12-31    118  1.164234  1.020985  1.397941     Alta   Alta
#
#        zf_value        zf_sw
# 0    Muito alto      Estável
# 1    Muito alto      Estável
# 2   Muito baixo      Estável
# 3   Muito baixo  Pouco baixo
# 4   Muito baixo  Muito baixo
# 5    Muito alto  Muito baixo
# 6   Pouco baixo      Estável
# 7       Estável   Muito alto
# 8       Estável      Estável
# 9    Muito alto   Muito alto
# 10   Pouco alto   Muito alto
# 11      Estável   Muito alto
# 12  Muito baixo  Pouco baixo
# 13      Estável  Muito baixo
# 14      Estável  Muito baixo
# 15  Pouco baixo      Estável
# 16  Muito baixo      Estável
# 17   Muito alto      Estável
# 18   Muito alto   Pouco alto
# 19      Estável   Muito alto
# 20   Muito alto   Muito alto
# 21      Estável      Estável
# 22      Estável      Estável
# 23   Pouco alto  Pouco baixo
# 24      Estável      Estável
# 25  Pouco baixo      Estável
# 26  Pouco baixo  Pouco baixo
# 27  Pouco baixo  Muito baixo
# 28      Estável  Muito baixo
# 29      Estável      Estável
# 30  Muito baixo      Estável
# 31  Pouco baixo      Estável
# 32   Muito alto   Pouco alto
# 33  Muito baixo   Pouco alto
# 34      Estável   Pouco alto
# 35   Pouco alto      Estável
# 36      Estável      Estável
# 37   Muito alto   Muito alto
# 38      Estável   Muito alto
# 39      Estável   Pouco alto
# 40      Estável  Pouco baixo
# 41  Pouco baixo  Muito baixo
# 42   Muito alto  Pouco baixo
# 43   Pouco alto   Pouco alto
# 44  Muito baixo   Pouco alto
# 45  Pouco baixo  Pouco baixo
# 46   Pouco alto  Muito baixo
# 47   Pouco alto      Estável
# 48  Pouco baixo   Pouco alto
# 49      Estável   Pouco alto
# 50   Pouco alto      Estável
# 51  Pouco baixo      Estável
# 52   Muito alto   Pouco alto
# 53      Estável   Pouco alto
# 54   Pouco alto   Muito alto
# 55  Muito baixo  Pouco baixo
# 56  Muito baixo  Muito baixo
# 57   Pouco alto  Muito baixo
# 58  Muito baixo  Pouco baixo
# 59   Muito alto   Muito alto

# %%
# Enviar para o excel para dar uma olhada...
df.to_excel('z-score atributo.xlsx', index=False)

# %%
# Define o estilo do seaborn
sns.set(style="whitegrid")

# Obtém as colunas numéricas e categóricas separadamente
numeric_columns = df.select_dtypes(include=['float64', 'int64'])
categorical_columns = df.select_dtypes(include=['category', 'object'])

# Define o tamanho da figura
plt.figure(figsize=(8, 12))

# Itera sobre cada coluna numérica do DataFrame
for i, column in enumerate(numeric_columns.columns):
    plt.subplot(3, 4, i+1)  # Ajusta o layout dos subplots conforme necessário
    sns.boxplot(y=column, data=df)  # Cria um boxplot para a coluna atual
    
    # Adiciona título à subplot
    plt.title(f"|> {column}")

# Ajusta o espaço entre os subplots verticais
plt.subplots_adjust(hspace=.5, wspace=2)

# Define o tamanho da figura
plt.figure(figsize=(12, 12))

# Itera sobre cada coluna categórica do DataFrame
for i, column in enumerate(categorical_columns.columns):
    plt.subplot(3, 1, i+1)  # Ajusta o layout dos subplots conforme necessário
    sns.countplot(y=column, data=df)  # Cria um countplot para a coluna atual
    
    # Adiciona título à subplot
    plt.title(f"Quantidade {column}")


# Ajusta o layout da figura e exibe os gráficos
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 27
#      25 # Itera sobre cada coluna categórica do DataFrame
#      26 for i, column in enumerate(categorical_columns.columns):
# ---> 27     plt.subplot(3, 1, i+1)  # Ajusta o layout dos subplots conforme necessário
#      28     sns.countplot(y=column, data=df)  # Cria um countplot para a coluna atual
#      30     # Adiciona título à subplot
#
# File c:\Users\fallg\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File c:\Users\fallg\anaconda3\Lib\site-packages\matplotlib\gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
#     597     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598         raise ValueError(
#     599             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600             f"not {num!r}"
#     601         )
#     602     i = j = num
#     603 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 3, not 4

# %%
sns.pairplot(df, corner=True, hue='zd_value'
             #, hue_order=['Pouco alto','Pouco baixo','Estável','Muito baixo','Muito alto']
            )

# %%
# Estável não aparece porque estamos com muitas casas depois da vírgula. Vamos Truncar.

# %%
import math

# Arredondar os valores Z para zero casas
df['N Zvalue'] = df['z_value'].apply(lambda x: round(x,0))

# Truncar os valores Z para duas casas decimais
#df['truncated_z_score'] = df['z_score'].apply(lambda x: math.trunc(x))

# Truncar os valores Z para duas casas decimais
#df['trunc_sw'] = df['sw'].apply(lambda x: math.trunc(x))

# Truncar os valores Z para duas casas decimais
#df['trunc_sw2'] = df['sw'].apply(lambda x: math.trunc(x))

#df['truncated_z_score2'] = df['z_score'].apply(lambda x: int(x * 100) / 100)


# Visualizar o DataFrame com as novas colunas
print(df)
# Out:
#          date  value        sw   z_value      z_sw zd_value  zd_sw  \
# 0  2021-01-31    124  0.999053  1.422245  0.000000     Alta  Média
# 1  2021-02-28    127  0.999053  1.622875  0.000000     Alta  Média
# 2  2021-03-31     80  0.999053 -1.520331  0.000000    Baixa  Média
# 3  2021-04-30     83  0.886850 -1.319701 -0.949585    Baixa  Baixa
# 4  2021-05-31     83  0.666667 -1.319701 -2.813022    Baixa  Baixa
# 5  2021-06-30    119  0.861027  1.087862 -1.168128     Alta  Baixa
# 6  2021-07-31     89  1.003448 -0.918441  0.037197    Baixa  Média
# 7  2021-08-31     99  1.247967 -0.249673  2.106590    Média   Alta
# 8  2021-09-30    101  1.014035 -0.115920  0.126795    Média  Média
# 9  2021-10-31    130  1.134021  1.823506  1.142245     Alta   Alta
# 10 2021-11-30    116  1.130293  0.887231  1.110699     Alta   Alta
# 11 2021-12-31    103  1.207612  0.017834  1.765061    Média   Alta
# 12 2022-01-31     86  0.924242 -1.119071 -0.633130    Baixa  Baixa
# 13 2022-02-28    104  0.844380  0.084711 -1.309011    Média  Baixa
# 14 2022-03-31    104  0.842407  0.084711 -1.325713    Média  Baixa
# 15 2022-04-30     92  0.983607 -0.717810 -0.130725    Baixa  Média
# 16 2022-05-31     81  0.945392 -1.453454 -0.454135    Baixa  Média
# 17 2022-06-30    118  0.989796  1.020985 -0.078344     Alta  Média
# 18 2022-07-31    119  1.060000  1.087862  0.515801     Alta   Alta
# 19 2022-08-31    103  1.227437  0.017834  1.932836    Média   Alta
# 20 2022-09-30    126  1.195876  1.555999  1.665736     Alta   Alta
# 21 2022-10-31    104  1.047170  0.084711  0.407217    Média  Média
# 22 2022-11-30     97  0.961765 -0.383427 -0.315575    Média  Média
# 23 2022-12-31    117  0.913793  0.954108 -0.721564     Alta  Baixa
# 24 2023-01-31    105  0.957958  0.151587 -0.347792    Média  Média
# 25 2023-02-28     93  0.963303 -0.650934 -0.302559    Baixa  Média
# 26 2023-03-31     88  0.899371 -0.985317 -0.843619    Baixa  Baixa
# 27 2023-04-30     89  0.846395 -0.918441 -1.291962    Baixa  Baixa
# 28 2023-05-31    100  0.879365 -0.182796 -1.012932    Média  Baixa
# 29 2023-06-30     96  0.996503 -0.450303 -0.021577    Média  Média
# 30 2023-07-31     85  1.040741 -1.185947  0.352807    Baixa  Média
# 31 2023-08-31     95  0.996390 -0.517180 -0.022539    Baixa  Média
# 32 2023-09-30    127  1.077193  1.622875  0.661307     Alta   Alta
# 33 2023-10-31     80  1.074733 -1.520331  0.640488    Baixa   Alta
# 34 2023-11-30     98  1.105072 -0.316550  0.897254    Média   Alta
# 35 2023-12-31    115  0.954397  0.820355 -0.377926     Alta  Média
# 36 2024-01-31    104  1.049669  0.084711  0.428367    Média  Média
# 37 2024-02-29    129  1.140984  1.756629  1.201174     Alta   Alta
# 38 2024-03-31    109  1.167235  0.419094  1.423346    Média   Alta
# 39 2024-04-30     99  1.063091 -0.249673  0.541964    Média   Alta
# 40 2024-05-31     99  0.882184 -0.249673 -0.989076    Média  Baixa
# 41 2024-06-30     94  0.853801 -0.584057 -1.229282    Baixa  Baixa
# 42 2024-07-31    119  0.925816  1.087862 -0.619813     Alta  Baixa
# 43 2024-08-31    112  1.058632  0.619724  0.504222     Alta   Alta
# 44 2024-09-30     81  1.068493 -1.453454  0.587679    Baixa   Alta
# 45 2024-10-31     89  0.903846 -0.918441 -0.805746    Baixa  Baixa
# 46 2024-11-30    112  0.867692  0.619724 -1.111720     Alta  Baixa
# 47 2024-12-31    111  1.000000  0.552848  0.008014     Alta  Média
# 48 2025-01-31     90  1.109929 -0.851564  0.938356    Baixa   Alta
# 49 2025-02-28    103  1.078014  0.017834  0.668257    Média   Alta
# 50 2025-03-31    115  0.987179  0.820355 -0.100487     Alta  Média
# 51 2025-04-30     91  0.987220 -0.784687 -0.100141    Baixa  Média
# 52 2025-05-31    130  1.105263  1.823506  0.898868     Alta   Alta
# 53 2025-06-30    108  1.068182  0.352217  0.585044    Média   Alta
# 54 2025-07-31    114  1.139159  0.753478  1.185728     Alta   Alta
# 55 2025-08-31     80  0.898810 -1.520331 -0.848372    Baixa  Baixa
# 56 2025-09-30     80  0.832827 -1.520331 -1.406791    Baixa  Baixa
# 57 2025-10-31    116  0.784091  0.887231 -1.819248     Alta  Baixa
# 58 2025-11-30     85  0.930464 -1.185947 -0.580480    Baixa  Baixa
# 59 2025-12-31    118  1.164234  1.020985  1.397941     Alta   Alta
#
#        zf_value        zf_sw  N Zvalue
# 0    Muito alto      Estável       1.0
# 1    Muito alto      Estável       2.0
# 2   Muito baixo      Estável      -2.0
# 3   Muito baixo  Pouco baixo      -1.0
# 4   Muito baixo  Muito baixo      -1.0
# 5    Muito alto  Muito baixo       1.0
# 6   Pouco baixo      Estável      -1.0
# 7       Estável   Muito alto      -0.0
# 8       Estável      Estável      -0.0
# 9    Muito alto   Muito alto       2.0
# 10   Pouco alto   Muito alto       1.0
# 11      Estável   Muito alto       0.0
# 12  Muito baixo  Pouco baixo      -1.0
# 13      Estável  Muito baixo       0.0
# 14      Estável  Muito baixo       0.0
# 15  Pouco baixo      Estável      -1.0
# 16  Muito baixo      Estável      -1.0
# 17   Muito alto      Estável       1.0
# 18   Muito alto   Pouco alto       1.0
# 19      Estável   Muito alto       0.0
# 20   Muito alto   Muito alto       2.0
# 21      Estável      Estável       0.0
# 22      Estável      Estável      -0.0
# 23   Pouco alto  Pouco baixo       1.0
# 24      Estável      Estável       0.0
# 25  Pouco baixo      Estável      -1.0
# 26  Pouco baixo  Pouco baixo      -1.0
# 27  Pouco baixo  Muito baixo      -1.0
# 28      Estável  Muito baixo      -0.0
# 29      Estável      Estável      -0.0
# 30  Muito baixo      Estável      -1.0
# 31  Pouco baixo      Estável      -1.0
# 32   Muito alto   Pouco alto       2.0
# 33  Muito baixo   Pouco alto      -2.0
# 34      Estável   Pouco alto      -0.0
# 35   Pouco alto      Estável       1.0
# 36      Estável      Estável       0.0
# 37   Muito alto   Muito alto       2.0
# 38      Estável   Muito alto       0.0
# 39      Estável   Pouco alto      -0.0
# 40      Estável  Pouco baixo      -0.0
# 41  Pouco baixo  Muito baixo      -1.0
# 42   Muito alto  Pouco baixo       1.0
# 43   Pouco alto   Pouco alto       1.0
# 44  Muito baixo   Pouco alto      -1.0
# 45  Pouco baixo  Pouco baixo      -1.0
# 46   Pouco alto  Muito baixo       1.0
# 47   Pouco alto      Estável       1.0
# 48  Pouco baixo   Pouco alto      -1.0
# 49      Estável   Pouco alto       0.0
# 50   Pouco alto      Estável       1.0
# 51  Pouco baixo      Estável      -1.0
# 52   Muito alto   Pouco alto       2.0
# 53      Estável   Pouco alto       0.0
# 54   Pouco alto   Muito alto       1.0
# 55  Muito baixo  Pouco baixo      -2.0
# 56  Muito baixo  Muito baixo      -2.0
# 57   Pouco alto  Muito baixo       1.0
# 58  Muito baixo  Pouco baixo      -1.0
# 59   Muito alto   Muito alto       1.0

# %%
sns.boxplot(data=df
            ,y='value', x='zd_value'
            ,order=['Baixa','Média','Alta']
           # ,order=['Pouco alto','Pouco baixo','Estável','Muito baixo','Muito alto']
           )
# Out:
# <Axes: xlabel='zd_value', ylabel='value'>

# %%
sns.boxplot(data=df
            ,y='value', x='zd_sw'
            ,order=['Baixa','Média','Alta']
           # ,order=['Pouco alto','Pouco baixo','Estável','Muito baixo','Muito alto']
           )
# Out:
# <Axes: xlabel='zd_sw', ylabel='value'>

# %%
sns.boxplot(data=df
            ,y='value', x='zf_sw'
            ,order=['Pouco alto','Pouco baixo','Estável','Muito baixo','Muito alto']
           )
# Out:
# <Axes: xlabel='zf_sw', ylabel='value'>

# %%
plt.figure(figsize=(12, 4)) # (largura, altura)
sns.boxplot(data=df
            ,y='z_value', x='zf_value'
            ,order=['Pouco alto','Pouco baixo','Estável','Muito baixo','Muito alto']
           )
plt.title('Z dos valores',fontsize=10) 
plt.xlabel('Classificação dos valores de Z',fontsize=8) 
plt.ylabel('Z valores',fontsize=8)
# Out:
# Text(0, 0.5, 'Z valores')

# %%
df.groupby('zd_value').min()
# Out:
#                date  value        sw   z_value      z_sw zd_sw     zf_value  \
# zd_value
# Alta     2021-01-31    111  0.784091  0.552848 -1.819248  Alta   Muito alto
# Baixa    2021-03-31     80  0.666667 -1.520331 -2.813022  Alta  Muito baixo
# Média    2021-08-31     96  0.842407 -0.450303 -1.325713  Alta      Estável
#
#             zf_sw  N Zvalue
# zd_value
# Alta      Estável       1.0
# Baixa     Estável      -2.0
# Média     Estável      -0.0

# %%
df.groupby('zd_value').max()
# Out:
#                date  value        sw   z_value      z_sw  zd_sw     zf_value  \
# zd_value
# Alta     2025-12-31    130  1.195876  1.823506  1.665736  Média   Pouco alto
# Baixa    2025-11-30     95  1.109929 -0.517180  0.938356  Média  Pouco baixo
# Média    2025-06-30    109  1.247967  0.419094  2.106590  Média      Estável
#
#                 zf_sw  N Zvalue
# zd_value
# Alta      Pouco baixo       2.0
# Baixa     Pouco baixo      -1.0
# Média     Pouco baixo      -0.0

# %%
# Amostra 
df.groupby('zd_value').sample()
# Out:
#          date  value        sw   z_value      z_sw zd_value  zd_sw  \
# 57 2025-10-31    116  0.784091  0.887231 -1.819248     Alta  Baixa
# 27 2023-04-30     89  0.846395 -0.918441 -1.291962    Baixa  Baixa
# 29 2023-06-30     96  0.996503 -0.450303 -0.021577    Média  Média
#
#        zf_value        zf_sw  N Zvalue
# 57   Pouco alto  Muito baixo       1.0
# 27  Pouco baixo  Muito baixo      -1.0
# 29      Estável      Estável      -0.0

# %%
df.groupby('zd_value')['value'].describe().sort_values(by='max',ascending=False)
# Out:
#           count        mean       std    min    25%    50%    75%    max
# zd_value
# Alta       21.0  119.714286  6.230111  111.0  115.0  118.0  126.0  130.0
# Média      18.0  102.000000  3.613699   96.0   99.0  103.0  104.0  109.0
# Baixa      21.0   86.380952  5.064348   80.0   81.0   86.0   90.0   95.0
