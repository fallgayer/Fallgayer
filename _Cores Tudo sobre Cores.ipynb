# %% [markdown]
# # Cores
# https://matplotlib.org/stable/gallery/color/named_colors.html#helper-function-for-plotting

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# Desativar avisos de expiração
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Suprimindo alertas sobre pacotes que irão expirar
warnings.filterwarnings("ignore")

# %%
import math

from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.BASE_COLORS, ncols=3, sort_colors=False)

# %%
plot_colortable(mcolors.TABLEAU_COLORS, ncols=2, sort_colors=False)

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
xkcd_fig = plot_colortable(mcolors.XKCD_COLORS)
xkcd_fig.savefig("XKCD_Colors.png")

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(current_palette) 
plt.show()

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(sns.color_palette("Greys")) 
plt.show()

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(sns.color_palette("terrain_r", 7)) 
plt.show()

# %%
import pandas as pd 
import seaborn as sns 
  
sns.palplot(sns.color_palette("deep", 10))

# %%
Os possíveis valores da paleta são:

    'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2 ',' Dark2_r ',' GnBu ',' GnBu_r ',' Verdes ',' Greens_r ',' Cinzas ',' Greys_r ',' OrRd ',' OrRd_r ',' Laranjas ',' Laranjas_r ',' PRGn ', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r ',' PuOr ',' PuOr_r ',' PuRd ',' PuRd_r ',' Roxos ',' Purples_r ',' RdBu ',' RdBu_r ',' RdGy ',' RdGy_r ',' RdPu ',' RdPu_r ', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral ',' Spectral_r ',' Wistia ',' Wistia_r ',' YlGn ',' YlGnBu ',' YlGnBu_r ',' YlGn_r ',' YlOrBr ',' YlOrBr_r ',' YlOrRd ',' YlOrRd_r ',' afmhot ', 'afmhot_r', 'outono', 'outono_r', 'binário', 'binary_r', 'osso', 'osso_r', 'brg', 'brg_r', 'bwr','bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r ',' gist_earth ',' gist_earth_r ',' gist_gray ',' gist_gray_r ',' gist_heat ',' gist_heat_r ',' gist_ncar ',' gist_ncar_r ',' gist_rainbow ',' gist_rainbow_r ',' gist_stern_r ',' gist_stern ' 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'grey', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire ',' icefire_r ',' inferno ',' inferno_r ',' jet ',' jet_r ',' magma ',' magma_r ',' mako ',' mako_r ',' nipy_spectral ',' nipy_spectral_r ',' oceano ', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prisma', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'sismic', 'seismic_r ',' spring ',' spring_r ',' summer ',' summer_r ',' tab10 ',' tab10_r ',' tab20 ′, 'tab20_r', 'tab20b', 'tab20b_r','tab20c', 'tab20c_r', 'terreno', 'terrenoin_r', 'turbo', 'turbo_r', 'crepúsculo', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag ',' vlag_r ',' inverno ',' inverno_r '
# Out:
#   Cell In[10], line 3
# ...

# %%
import pandas as pd 
import seaborn as sns
x=10 # escolher a quantidade de cores que se quer na paleta
  
sns.palplot(sns.color_palette("muted", x)) 
sns.palplot(sns.color_palette("Accent", x)) 
sns.palplot(sns.color_palette("bright", x)) 
sns.palplot(sns.color_palette("mako", x)) 
sns.palplot(sns.color_palette("dark", x))
sns.palplot(sns.color_palette("magma_r", x))
sns.palplot(sns.color_palette("tab20b_r", x))
sns.palplot(sns.color_palette("BuGn_r", x))

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(current_palette) 
plt.show()

# %%
sns.palplot(sns.color_palette("Set3", x))

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(sns.color_palette("Greys")) 
plt.show()

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(sns.color_palette("terrain_r", 10)) 
plt.show()

# %%
import pandas as pd 
import seaborn as sns 
  
sns.palplot(sns.color_palette("deep", 10))

# %%
sns.palplot(sns.color_palette("Blues", 10))

# %%
sns.palplot(sns.color_palette("Blues_r", 10))

# %%
sns.palplot(sns.color_palette("bright", 10))

# %%
# Criar a própria paleta de cores...

import pandas as pd 
import seaborn as sns 
  
color = ["green", "White", "Red", "Yellow", "#789", "#123456","#FFEEDD","#998877","#680"] 
sns.set_palette(color) 
sns.palplot(sns.color_palette())

# %%
sns.set_theme(style="white", palette=None)
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <Axes: >

# %%
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sns.set_theme(style="whitegrid", palette="twilight_shifted_r")
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <Axes: >

# %%
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sns.set_theme(style="whitegrid", palette="Blues")
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <Axes: >

# %%
# É possível configurar vários ítens de uma única vez em uma variável e depois chama-la dentro do set_theme =rc
configura_grafico = {"axes.spines.right": False, "axes.spines.top": False}

fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sns.set_theme(style="ticks", rc=configura_grafico)
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <Axes: >

# %%
# É possível configurar vários ítens de uma única vez em uma variável e depois chama-la dentro do set_theme =rc
configura_grafico = {"axes.spines.right": True, "axes.spines.top": True}

fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sns.set_theme(style="ticks", rc=configura_grafico)
sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# <Axes: >

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def sinplot(n=10, flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, n + 1):
        plt.plot(x, np.sin(x + i * .5) * (n + 2 - i) * flip)

# %%
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sinplot()

# %%
sns.set_theme()
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sinplot()

# %%
sns.set_style("whitegrid")
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sinplot()

# %%
sns.set_style("dark")
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sinplot()

# %%
sns.set_style("white")
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sinplot()

# %%
sns.set_style("ticks")
fig, g=plt.subplots(figsize=(4, 2), layout='constrained')
sinplot()

# %%
sinplot()
sns.despine()

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data);

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);

# %%
sns.set_style("whitegrid")
sns.boxplot(data=data, palette="deep")
sns.despine(left=True)

# %%
f = plt.figure(figsize=(6, 6))
gs = f.add_gridspec(2, 2)

with sns.axes_style("darkgrid"):
    ax = f.add_subplot(gs[0, 0])
    sinplot(6)

with sns.axes_style("white"):
    ax = f.add_subplot(gs[0, 1])
    sinplot(6)

with sns.axes_style("ticks"):
    ax = f.add_subplot(gs[1, 0])
    sinplot(6)

with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[1, 1])
    sinplot(6)

f.tight_layout()

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sinplot()

# %%
sns.set_context("paper")
sinplot()

# %%
sns.set_context("talk")
sinplot()

# %%
sns.set_context("poster")
sinplot()

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sinplot()
