# %% [markdown]
# # Matplotlib - Desenhando as visões gráficas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from scipy.stats import linregress
import warnings

# Desativar avisos de expiração
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 3))
# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# em vez de ax ou axs dá tranquilamente para usar qualquer letra, como o g
fig, g = plt.subplots(1, 1, figsize=(8, 3))
# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
df.head(2)

# %%
# em vez de ax ou axs dá tranquilamente para usar qualquer letra, como o g
fig, g = plt.subplots(1, 1, figsize=(8, 3))
sns.boxplot(df)
# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# em vez de ax ou axs dá tranquilamente para usar qualquer letra, como o g
fig, g = plt.subplots(1,3, figsize=(12, 3))
sns.boxplot(df
            ,ax=g[0]
           )
sns.countplot(df, x="species"
             ,ax=g[1]
             )
sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
           ,ax=g[2]
           )

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# %%
# incluir uma segunda linha, com um gráfico que ocupe toda a linha
fig, g = plt.subplots(2,3, figsize=(12, 3))
sns.boxplot(df
            ,ax=g[0,0]
           )
sns.countplot(df, x="species"
             ,ax=g[0,1]
             )
sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
           ,ax=g[0,2]
           )


# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# Aqui foi feito uma matriz, deu-se nomes para cada posição. É só colocar o nome dessa posição em cada gráfico 
fig, g = plt.subplot_mosaic([['eup', 'd'],
                               ['e', 'd'],
                                ['e','ddonw']],width_ratios=[5, 5],layout='constrained',figsize=(12, 6))

# %%
# Buscando as colunas numéricas para fazer correlação
colnum = df.select_dtypes(include=['float64', 'int64'])

# %%
# Aqui foi feito uma matriz, deu-se nomes para cada posição. É só colocar o nome dessa posição em cada gráfico 
fig, g = plt.subplot_mosaic([['eup', 'd'],
                             ['e', 'd'],
                             ['e','ddown'],
                             ['bem embaixo','bem embaixo'],
                             ['bem embaixo','bem embaixo']
                            ],width_ratios=[5, 5],layout='constrained',figsize=(12, 6))

sns.boxplot(df,ax=g['e'])
sns.countplot(df, x="species",ax=g['ddown'])
sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm",ax=g['d'])
sns.barplot(df, x="island", y="body_mass_g",ax=g['eup'])

sns.heatmap(colnum.corr(), annot=True, cmap='coolwarm', ax=g['bem embaixo'])

g['ddown'].set_title('Testando o título...')

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
fig, ax = plt.subplot_mosaic(
    [
        ['main', 'freq'],
        ['main', 'color'],
        ['main', 'linestyle'],
    ],
    width_ratios=[5, 1],
    layout='constrained',
)

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# %%
numeric_columns.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Carregando o conjunto de dados penguins
penguins = sns.load_dataset("penguins")

# Selecionando apenas as colunas numéricas para a matriz de correlação
numeric_columns = penguins.select_dtypes(include=['float64', 'int64'])

# Criando uma figura e os eixos para os gráficos
fig, axs = plt.subplots(3, 2, figsize=(12, 15))

# Gráfico 1: Scatter plot de 'bill_length_mm' vs 'bill_depth_mm'
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', ax=axs[0, 0])
axs[0, 0].set_title('Scatter Plot: Bill Length vs Bill Depth')

# Gráfico 2: Box plot de 'species' vs 'bill_length_mm'
sns.boxplot(data=penguins, x='species', y='bill_length_mm', ax=axs[0, 1])
axs[0, 1].set_title('Box Plot: Species vs Bill Length')

# Gráfico 3: Histograma de 'flipper_length_mm'
sns.histplot(data=penguins, x='flipper_length_mm', kde=True, ax=axs[1, 0])
axs[1, 0].set_title('Histogram: Flipper Length')

# Gráfico 4: Contagem de espécies
sns.countplot(data=penguins, x='species', ax=axs[1, 1])
axs[1, 1].set_title('Species Count')

# Removendo os eixos dos subplots vazios
plt.delaxes(axs[2, 0])
plt.delaxes(axs[2, 1])

# Gráfico 5: Matriz de correlação // Aqui criou-se outra visão, o lá de cima deu erro, esse não, foi a escala que ficou fora
corr_ax = fig.add_subplot(3, 1, 3)
sns.heatmap(numeric_columns.corr(), annot=True, cmap='coolwarm', ax=corr_ax)
corr_ax.set_title('Correlation Matrix')

# Ajustando o layout
plt.tight_layout()

# Mostrando os gráficos
plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(12, 5))
corr_ax = fig.add_subplot(1, 1, 1)
sns.heatmap(numeric_columns.corr(), annot=True, cmap='coolwarm', ax=corr_ax)
corr_ax.set_title('Correlation Matrix')
## Ajustando o layout
plt.tight_layout()

# Mostrando os gráficos
plt.show()

# %%
# criando 3 x 3
fig, g = plt.subplot_mosaic([[1,2,3],
                            [1,2,3],
                            [1,2,3]], figsize=(12, 5))
# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# criando 3 x 3
fig, g = plt.subplot_mosaic([[1,2,3],
                            [4,5,6],
                            [7,8,9]], figsize=(12, 5))

sns.countplot(data=penguins, x='species', ax=g[5])
g[5].set_title('Teste animal...')

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# criando 3 x 3
# Fazer o gráfico ocupar uma área maior
fig, g = plt.subplot_mosaic([[1,2,3],
                            [4,5,5],
                            [7,5,5]], figsize=(12, 5))

sns.countplot(data=penguins, x='species', ax=g[5])
g[5].set_title('Teste animal...')

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# criando 4 x 4

fig, g = plt.subplot_mosaic([[1,2],
                            [3,4]], figsize=(12, 5))

sns.countplot(data=penguins, x='species', ax=g[3])
g[3].set_title('Teste animal...')

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# criando 4 x 4
# Posso colocar na matriz números e palavras?

fig, g = plt.subplot_mosaic([[1,2],
                            [3,'teste de posição']], figsize=(12, 5))

sns.countplot(data=penguins, x='species', ax=g['teste de posição'])
g['teste de posição'].set_title('Teste animal...')

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# Testar com gráficos grandes

fig, g = plt.subplot_mosaic([[1,2],
                             [1,'teste de posição']], figsize=(12, 5))

sns.countplot(data=penguins, x='species', ax=g['teste de posição'])
g['teste de posição'].set_title('Teste animal...')


sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', ax=g[1])

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# Mostrar o gráfico com as 3 ilhas e os 3 gráficos separados
sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm")

# %%
fig, g = plt.subplot_mosaic([[1,2,3],
                             [4,5,6],
                             [7,8,9]])
# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
fig, g = plt.subplot_mosaic([[1,1,1,3,3],
                             [1,1,1,7,7],
                             [1,1,1,11,11]]
                           ,figsize=(12, 6))

sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1], order=2)
sns.regplot(data=df[df['species']=='Adelie'], order=2
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3])
sns.regplot(data=df[df['species']=='Chinstrap'], order=2
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7])
sns.regplot(data=df[df['species']=='Gentoo'], order=2
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11])

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
fig, g = plt.subplot_mosaic([[1,1,1,3,3],
                             [1,1,1,7,7],
                             [1,1,1,11,11]]
                           ,figsize=(12, 6))

sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1], order=3)
sns.regplot(data=df[df['species']=='Adelie'], order=3
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3])
sns.regplot(data=df[df['species']=='Chinstrap'], order=3
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7])
sns.regplot(data=df[df['species']=='Gentoo'], order=3
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11])

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
df['species'].unique()

# %%
df[df['species']=='Adelie']

# %%
fig, g = plt.subplot_mosaic([[1,1,1,3,3],
                             [1,1,1,7,7],
                             [1,1,1,11,11]]
                           ,figsize=(12, 6))

sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1], logx=True)
sns.regplot(data=df[df['species']=='Adelie'],logx=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3])
sns.regplot(data=df[df['species']=='Chinstrap'], logx=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7])
sns.regplot(data=df[df['species']=='Gentoo'], logx=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11])

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
fig, g = plt.subplot_mosaic([[1,1,1,3,3],
                             [1,1,1,7,7],
                             [1,1,1,11,11]]
                           ,figsize=(12, 6))

sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1],lowess=True)
sns.regplot(data=df[df['species']=='Adelie'],lowess=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3])
sns.regplot(data=df[df['species']=='Chinstrap'],lowess=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7])
sns.regplot(data=df[df['species']=='Gentoo'],lowess=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11])

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
fig, g = plt.subplot_mosaic([[1,1,1,3,3],
                             [1,1,1,7,7],
                             [1,1,1,11,11]]
                           ,figsize=(12, 6))

sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1], x_estimator=np.mean, order=2)

sns.regplot(data=df[df['species']=='Adelie'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3])
sns.regplot(data=df[df['species']=='Chinstrap'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7])
sns.regplot(data=df[df['species']=='Gentoo'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11])

# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
fig, g = plt.subplot_mosaic([[1,1,1,3,3],
                             [1,1,1,7,7],
                             [1,1,1,11,11]]
                           ,figsize=(12, 6))

sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1], ci=99, marker="x", color=".3", line_kws=dict(color="r"))

sns.regplot(data=df[df['species']=='Adelie'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3]
           , ci=99, marker="o", color=".6", line_kws=dict(color="b"))
sns.regplot(data=df[df['species']=='Chinstrap'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7]
           , ci=99, marker="^", color=".6", line_kws=dict(color="b"))
sns.regplot(data=df[df['species']=='Gentoo'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11]
           , ci=99, marker="+", color=".6", line_kws=dict(color="b"))



# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()

# %%
# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell
f, g = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=g)
g.set_title('Mapa de calor por mês e ano dos vôos')

# %%
import seaborn as sns
sns.set_theme()

mpg = sns.load_dataset("mpg")
sns.catplot(
    data=mpg, x="cylinders", y="acceleration", hue="weight",
    native_scale=True, zorder=1
)
sns.regplot(
    data=mpg, x="cylinders", y="acceleration",
    scatter=False, truncate=False, order=2, color=".2"
)

# %%
mpg.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example dataset of brain network correlations
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Pull out a specific subset of networks
used_networks = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Compute the correlation matrix and average over networks
corr_df = df.corr().groupby(level="network").mean()
corr_df.index = corr_df.index.astype(int)
corr_df = corr_df.sort_index().T

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 6))

# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=corr_df, bw_adjust=.5, cut=1, linewidth=1, palette="Set3")

# Finalize the figure
ax.set(ylim=(-.7, 1.05))
sns.despine(left=True, bottom=True)

# %%
corr_df

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df=diamonds

# %%
df.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
df['cut'].unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df['color'].unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df['clarity'].unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
fig, g = plt.subplot_mosaic([[1,1,2,2],
                             [1,1,2,2],
                             [3,3,4,4],
                             [3,3,4,4]]
                           ,figsize=(12, 6))
sns.histplot(data=df, x="color",kde=True, ax=g[1])

"""
sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
            ,ax=g[1], ci=99, marker="x", color=".3", line_kws=dict(color="r"))

sns.regplot(data=df[df['species']=='Adelie'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[3]
           , ci=99, marker="o", color=".6", line_kws=dict(color="b"))
sns.regplot(data=df[df['species']=='Chinstrap'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[7]
           , ci=99, marker="^", color=".6", line_kws=dict(color="b"))
sns.regplot(data=df[df['species']=='Gentoo'], robust=True
            ,x="bill_length_mm", y="flipper_length_mm",ax=g[11]
           , ci=99, marker="+", color=".6", line_kws=dict(color="b"))
"""


# Ajustando o layout
plt.tight_layout()
# Mostrando os gráficos
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 7
#       1 fig, g = plt.subplot_mosaic([[1,1,2,2],
#       2                              [1,1,2,2],
#       3                              [3,3,4,4],
#       4                              [3,3,4,4]]
#       5                            ,figsize=(12, 6))
#       6 sns.histplot(data=df, x="color",kde=True, ax=g[1])
# ----> 7 sns.histplot(data=df,ax=g[2])
#       8 """
#       9 sns.regplot(data=df, x="bill_length_mm", y="flipper_length_mm"
#      10             ,ax=g[1], ci=99, marker="x", color=".3", line_kws=dict(color="r"))
#    (...)
#      20            , ci=99, marker="+", color=".6", line_kws=dict(color="b"))
#      21 """
#      24 # Ajustando o layout
#
# ...

# %%
sns.histplot(data=df)
